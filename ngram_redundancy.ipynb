# %%
from os import path
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from lxml import etree
import spacy
from glob import glob
from unicodedata import normalize

# %%
nlp = spacy.load('fr_core_news_md')

# %%
# %matplotlib inline

# %%
def lemmatize(path):
    list_lemma = []
    with open(path, encoding="utf8") as file:
        tree = etree.parse(file)
        if tree.findall(".//p"):
            for paragraphe in tree.findall(".//p"):
                if paragraphe.text:
                    clean_text = normalize("NFKD", paragraphe.text)
                    docs = nlp(clean_text)
                    for token in docs:
                        if token.pos_ != "PUNCT" and "SPACE" and "X" and "SYM":
                            list_lemma.append(token.lemma_)
    return list_lemma

# %%
def postaggize(path):
    list_pos = []
    with open(path, encoding="utf8") as file:
        tree = etree.parse(file)
        if tree.findall(".//p"):
            for paragraphe in tree.findall(".//p"):
                if paragraphe.text:
                    clean_text = normalize("NFKD", paragraphe.text)
                    docs = nlp(clean_text)
                    for token in docs:
                        if token.pos_ != "PUNCT" and "SPACE" and "X" and "SYM":
                            list_pos.append(token.pos_)
    return list_pos

# %%
def bigrammize(list_lemma):
    list_bigram = []
    for indice_lemma in range(len(list_lemma)-1):
        bigram = list_lemma[indice_lemma]+'_'+list_lemma[indice_lemma+1]
        list_bigram.append(bigram)
    return list_bigram

# %%
def ngrammize(list_lemma, n):
    list_ngram = []
    for indice_lemma in range(len(list_lemma) - n):
        ngram = ""
        for i in range(n):
            soudure = "_" if i != n-1 else ""
            ngram+=list_lemma[indice_lemma+i]+soudure
        list_ngram.append(ngram)
    return list_ngram

# %%
path_test = 'corpus_test/1829_Hugo-Victor_Le-dernier-jour-d-un-condamne.xml'

# %%
list_lemma_hugo = lemmatize(path_test)
list_bigram_hugo = bigrammize(list_lemma_hugo)    
print(list_bigram_hugo)
# Out:
# ['il_n’', 'n’_y', 'y_avoir', 'avoir_en', 'en_tête', 'tête_un', 'un_première', 'première_édition', 'édition_de', 'de_ce', 'ce_ouvrage', 'ouvrage_publié', 'publié_d’', 'd’_abord', 'abord_sans', 'sans_nom', 'nom_d’', 'd’_auteur', 'auteur_que', 'que_le', 'le_quelque', 'quelque_ligne', 'ligne_qu’', 'qu’_on', 'on_aller', 'aller_lire', 'lire_il', 'il_y', 'y_avoir', 'avoir_deux', 'deux_manière', 'manière_de', 'de_se', 'se_rendre', 'rendre_compte', 'compte_de', 'de_l’', 'l’_existence', 'existence_de', 'de_ce', 'ce_livre', 'livre_ou', 'ou_il', 'il_y', 'y_avoir', 'avoir_avoir', 'avoir_en', 'en_effet', 'effet_un', 'un_liasse', 'liasse_de', 'de_papier', 'papier_jaune', 'jaune_et', 'et_inégau', 'inégau_sur', 'sur_lequel', 'lequel_on', 'on_avoir', 'avoir_trouvé', 'trouvé_enregistréer', 'enregistréer_un', 'un_à', 'à_un', 'un_le', 'le_dernière', 'dernière_penséer', 'penséer_d’', 'd’_un', 'un_misérable', 'misérable_ou', 'ou_il', 'il_s’', 's’_être', 'être_rencontré', 'rencontré_un', 'un_homme', 'homme_un', 'un_rêveur', 'rêveur_occupé', 'occupé_à', 'à_observer', 'observer_le', 'le_nature', 'nature_au', 'au_profit', 'profit_de', 'de_l’', 'l’_art', 'art_un', 'un_philosophe', 'philosophe_un', 'un_poëte', 'poëte_que', 'que_savoir', 'savoir_je', 'je_dont', 'dont_ce', 'ce_idée', 'idée_avoir', 'avoir_été', 'été_le', 'le_fantaisie', 'fantaisie_qui', 'qui_l’', 'l’_avoir', 'avoir_prendre', 'prendre_ou', 'ou_plutôt', 'plutôt_s’', 's’_être', 'être_laissé', 'laissé_prendre', 'prendre_par', 'par_lui', 'lui_et', 'et_n’', 'n’_avoir', 'avoir_pouvoir', 'pouvoir_s’', 's’_en', 'en_débarrasser', 'débarrasser_qu’', 'qu’_en', 'en_le', 'le_jeter', 'jeter_dans', 'dans_un', 'un_livre', 'livre_de', 'de_ce', 'ce_deux', 'deux_explication', 'explication_le', 'le_lecteur', 'lecteur_choisir', 'choisir_celui', 'celui_qu’', 'qu’_il', 'il_vouloir', 'vouloir_comme', 'comme_on', 'on_le', 'le_voir', 'voir_à', 'à_l’', 'l’_époque', 'époque_où', 'où_ce', 'ce_livre', 'livre_être', 'être_publié', 'publié_l’', 'l’_auteur', 'auteur_ne', 'ne_juger', 'juger_pas', 'pas_à', 'à_propos', 'propos_de', 'de_dire', 'dire_dès', 'dès_lors', 'lors_tout', 'tout_son', 'son_pensée', 'pensée_il', 'il_aimer', 'aimer_mieux', 'mieux_attendre', 'attendre_qu’', 'qu’_lui', 'lui_fût', 'fût_comprendre', 'comprendre_et', 'et_voir', 'voir_si', 'si_lui', 'lui_le', 'le_être', 'être_lui', 'lui_l’', 'l’_avoir', 'avoir_été.', 'été._l’', 'l’_auteur', 'auteur_aujourd’hui', 'aujourd’hui_pouvoir', 'pouvoir_démasquer', 'démasquer_l’', 'l’_idée', 'idée_politique', 'politique_l’', 'l’_idée', 'idée_social', 'social_qu’', 'qu’_il', 'il_avoir', 'avoir_vouloir', 'vouloir_populariser', 'populariser_sous', 'sous_ce', 'ce_innocent', 'innocent_et', 'et_candide', 'candide_forme', 'forme_littérair', 'littérair_il', 'il_déclare', 'déclare_donc', 'donc_ou', 'ou_plutôt', 'plutôt_il', 'il_avoue', 'avoue_hautement', 'hautement_que', 'que_le', 'le_dernier', 'dernier_jour', 'jour_d’', 'd’_un', 'un_condamné', 'condamné_n’', 'n’_être', 'être_autre', 'autre_chose', 'chose_qu’', 'qu’_un', 'un_plaidoyer', 'plaidoyer_direct', 'direct_ou', 'ou_indirect', 'indirect_comme', 'comme_on', 'on_vouloir', 'vouloir_pour', 'pour_l’', 'l’_abolition', 'abolition_de', 'de_le', 'le_peine', 'peine_de', 'de_mort', 'mort_ce', 'ce_qu’', 'qu’_il', 'il_avoir', 'avoir_avoir', 'avoir_dessein', 'dessein_de', 'de_faire', 'faire_ce', 'ce_qu’', 'qu’_il', 'il_vouloir', 'vouloir_que', 'que_le', 'le_postérité', 'postérité_vît', 'vît_dans', 'dans_son', 'son_œuvre', 'œuvre_si', 'si_jamais', 'jamais_lui', 'lui_s’', 's’_occupe', 'occupe_de', 'de_si', 'si_peu', 'peu_ce', 'ce_n’', 'n’_être', 'être_pas', 'pas_le', 'le_défense', 'défense_spécial', 'spécial_et', 'et_toujours', 'toujours_facile', 'facile_et', 'et_toujours', 'toujours_transitoire', 'transitoire_de', 'de_tel', 'tel_ou', 'ou_tel', 'tel_criminel', 'criminel_choisir', 'choisir_de', 'de_tel', 'tel_ou', 'ou_tel', 'tel_accusé', 'accusé_d’',  ...

# %%
Counter(list_bigram_hugo).most_common(5)
# Out:
# [('de_le', 180),
#  ('j’_avoir', 165),
#  ('c’_être', 157),
#  ('dans_le', 136),
#  ('d’_un', 123)]

# %%
list_pos_hugo = postaggize(path_test)
list_bigram_pos_hugo = bigrammize(list_pos_hugo)    
print(list_bigram_pos_hugo)
# Out:
# ['PRON_ADV', 'ADV_PRON', 'PRON_VERB', 'VERB_ADP', 'ADP_NOUN', 'NOUN_DET', 'DET_ADJ', 'ADJ_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_VERB', 'VERB_ADP', 'ADP_ADV', 'ADV_ADP', 'ADP_NOUN', 'NOUN_ADP', 'ADP_NOUN', 'NOUN_SCONJ', 'SCONJ_DET', 'DET_DET', 'DET_NOUN', 'NOUN_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_VERB', 'VERB_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_NUM', 'NUM_NOUN', 'NOUN_ADP', 'ADP_PRON', 'PRON_VERB', 'VERB_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_CCONJ', 'CCONJ_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_ADP', 'ADP_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_NOUN', 'NOUN_ADJ', 'ADJ_CCONJ', 'CCONJ_NOUN', 'NOUN_ADP', 'ADP_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_VERB', 'VERB_DET', 'DET_NOUN', 'NOUN_DET', 'DET_DET', 'DET_NOUN', 'NOUN_VERB', 'VERB_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_CCONJ', 'CCONJ_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_ADJ', 'ADJ_DET', 'DET_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_PROPN', 'PROPN_ADP', 'ADP_VERB', 'VERB_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_SCONJ', 'SCONJ_VERB', 'VERB_PRON', 'PRON_PRON', 'PRON_DET', 'DET_NOUN', 'NOUN_VERB', 'VERB_VERB', 'VERB_DET', 'DET_NOUN', 'NOUN_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_CCONJ', 'CCONJ_SYM', 'SYM_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_VERB', 'VERB_ADP', 'ADP_PRON', 'PRON_CCONJ', 'CCONJ_ADV', 'ADV_AUX', 'AUX_VERB', 'VERB_PRON', 'PRON_ADP', 'ADP_VERB', 'VERB_SCONJ', 'SCONJ_ADP', 'ADP_DET', 'DET_VERB', 'VERB_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NUM', 'NUM_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_VERB', 'VERB_PRON', 'PRON_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_SCONJ', 'SCONJ_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_AUX', 'AUX_VERB', 'VERB_DET', 'DET_NOUN', 'NOUN_ADV', 'ADV_VERB', 'VERB_ADV', 'ADV_ADP', 'ADP_NOUN', 'NOUN_ADP', 'ADP_VERB', 'VERB_ADP', 'ADP_ADV', 'ADV_ADJ', 'ADJ_DET', 'DET_VERB', 'VERB_PRON', 'PRON_VERB', 'VERB_ADV', 'ADV_VERB', 'VERB_SCONJ', 'SCONJ_PRON', 'PRON_NOUN', 'NOUN_VERB', 'VERB_CCONJ', 'CCONJ_VERB', 'VERB_SCONJ', 'SCONJ_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_DET', 'DET_NOUN', 'NOUN_ADV', 'ADV_VERB', 'VERB_NOUN', 'NOUN_DET', 'DET_NOUN', 'NOUN_ADJ', 'ADJ_DET', 'DET_NOUN', 'NOUN_ADJ', 'ADJ_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_VERB', 'VERB_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_CCONJ', 'CCONJ_NOUN', 'NOUN_NOUN', 'NOUN_ADJ', 'ADJ_PRON', 'PRON_VERB', 'VERB_ADV', 'ADV_CCONJ', 'CCONJ_NOUN', 'NOUN_PRON', 'PRON_VERB', 'VERB_ADV', 'ADV_SCONJ', 'SCONJ_DET', 'DET_ADJ', 'ADJ_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADV', 'ADV_AUX', 'AUX_ADJ', 'ADJ_NOUN', 'NOUN_SCONJ', 'SCONJ_DET', 'DET_NOUN', 'NOUN_ADJ', 'ADJ_CCONJ', 'CCONJ_ADJ', 'ADJ_SCONJ', 'SCONJ_PRON', 'PRON_VERB', 'VERB_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_ADP', 'ADP_NOUN', 'NOUN_PRON', 'PRON_PRON', 'PRON_PRON', 'PRON_AUX', 'AUX_VERB', 'VERB_NOUN', 'NOUN_ADP', 'ADP_VERB', 'VERB_PRON', 'PRON_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_SCONJ', 'SCONJ_DET', 'DET_NUM', 'NUM_ADJ', 'ADJ_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_SCONJ', 'SCONJ_ADV', 'ADV_PRON', 'PRON_PRON', 'PRON_VERB', 'VERB_ADP', 'ADP_SCONJ', 'SCONJ_ADV', 'ADV_DET', 'DET_ADV', 'ADV_AUX', 'AUX_ADV', 'ADV_DET', 'DET_NOUN', 'NOUN_ADJ', 'ADJ_CCONJ', 'CCONJ_ADV', 'ADV_ADJ', 'ADJ_CCONJ', 'CCONJ_ADV', 'ADV_ADJ', 'ADJ_ADP', 'ADP_ADJ', 'ADJ_CCONJ', 'CCONJ_ADJ', 'ADJ_ADJ', 'ADJ_VERB', 'VERB_ADP', 'ADP_ADJ', 'ADJ_CCONJ', 'CCONJ_ADJ', 'ADJ_PROPN', 'PROPN_ADP', 'ADP_NOUN', 'NOUN_PRON', 'PRON_AUX', 'AUX_DET', 'DET_NOUN', 'NOUN_ADJ', 'ADJ_CCONJ', 'CCONJ_ADJ', 'ADJ_ADP', 'ADP_ADJ', 'ADJ_DET', 'DET_PROPN', 'PROPN_ADJ', 'ADJ_CCONJ', 'CCONJ_ADP', 'ADP_VERB', 'VERB_PRON', 'PRON_AUX', 'AUX_DET', 'DET_ADJ', 'ADJ_NOUN', 'NOUN_ADP', 'ADP_NOUN', 'NOUN_ADP', 'ADP_DET', 'DET_NOUN', 'NOUN_PROPN', 'PROPN_CCONJ', 'CCONJ_NOUN', 'NOUN_ADP', ' ...

# %%
Counter(list_bigram_pos_hugo).most_common(5)
# Out:
# [('DET_NOUN', 3984),
#  ('NOUN_ADP', 2344),
#  ('PRON_VERB', 1988),
#  ('ADP_NOUN', 1749),
#  ('ADP_DET', 1707)]

# %%
list_ngram_hugo = ngrammize(list_lemma_hugo, 4)    
print(list_ngram_hugo)
# Out:
# ['il_n’_y_avoir', 'n’_y_avoir_en', 'y_avoir_en_tête', 'avoir_en_tête_un', 'en_tête_un_première', 'tête_un_première_édition', 'un_première_édition_de', 'première_édition_de_ce', 'édition_de_ce_ouvrage', 'de_ce_ouvrage_publié', 'ce_ouvrage_publié_d’', 'ouvrage_publié_d’_abord', 'publié_d’_abord_sans', 'd’_abord_sans_nom', 'abord_sans_nom_d’', 'sans_nom_d’_auteur', 'nom_d’_auteur_que', 'd’_auteur_que_le', 'auteur_que_le_quelque', 'que_le_quelque_ligne', 'le_quelque_ligne_qu’', 'quelque_ligne_qu’_on', 'ligne_qu’_on_aller', 'qu’_on_aller_lire', 'on_aller_lire_il', 'aller_lire_il_y', 'lire_il_y_avoir', 'il_y_avoir_deux', 'y_avoir_deux_manière', 'avoir_deux_manière_de', 'deux_manière_de_se', 'manière_de_se_rendre', 'de_se_rendre_compte', 'se_rendre_compte_de', 'rendre_compte_de_l’', 'compte_de_l’_existence', 'de_l’_existence_de', 'l’_existence_de_ce', 'existence_de_ce_livre', 'de_ce_livre_ou', 'ce_livre_ou_il', 'livre_ou_il_y', 'ou_il_y_avoir', 'il_y_avoir_avoir', 'y_avoir_avoir_en', 'avoir_avoir_en_effet', 'avoir_en_effet_un', 'en_effet_un_liasse', 'effet_un_liasse_de', 'un_liasse_de_papier', 'liasse_de_papier_jaune', 'de_papier_jaune_et', 'papier_jaune_et_inégau', 'jaune_et_inégau_sur', 'et_inégau_sur_lequel', 'inégau_sur_lequel_on', 'sur_lequel_on_avoir', 'lequel_on_avoir_trouvé', 'on_avoir_trouvé_enregistréer', 'avoir_trouvé_enregistréer_un', 'trouvé_enregistréer_un_à', 'enregistréer_un_à_un', 'un_à_un_le', 'à_un_le_dernière', 'un_le_dernière_penséer', 'le_dernière_penséer_d’', 'dernière_penséer_d’_un', 'penséer_d’_un_misérable', 'd’_un_misérable_ou', 'un_misérable_ou_il', 'misérable_ou_il_s’', 'ou_il_s’_être', 'il_s’_être_rencontré', 's’_être_rencontré_un', 'être_rencontré_un_homme', 'rencontré_un_homme_un', 'un_homme_un_rêveur', 'homme_un_rêveur_occupé', 'un_rêveur_occupé_à', 'rêveur_occupé_à_observer', 'occupé_à_observer_le', 'à_observer_le_nature', 'observer_le_nature_au', 'le_nature_au_profit', 'nature_au_profit_de', 'au_profit_de_l’', 'profit_de_l’_art', 'de_l’_art_un', 'l’_art_un_philosophe', 'art_un_philosophe_un', 'un_philosophe_un_poëte', 'philosophe_un_poëte_que', 'un_poëte_que_savoir', 'poëte_que_savoir_je', 'que_savoir_je_dont', 'savoir_je_dont_ce', 'je_dont_ce_idée', 'dont_ce_idée_avoir', 'ce_idée_avoir_été', 'idée_avoir_été_le', 'avoir_été_le_fantaisie', 'été_le_fantaisie_qui', 'le_fantaisie_qui_l’', 'fantaisie_qui_l’_avoir', 'qui_l’_avoir_prendre', 'l’_avoir_prendre_ou', 'avoir_prendre_ou_plutôt', 'prendre_ou_plutôt_s’', 'ou_plutôt_s’_être', 'plutôt_s’_être_laissé', 's’_être_laissé_prendre', 'être_laissé_prendre_par', 'laissé_prendre_par_lui', 'prendre_par_lui_et', 'par_lui_et_n’', 'lui_et_n’_avoir', 'et_n’_avoir_pouvoir', 'n’_avoir_pouvoir_s’', 'avoir_pouvoir_s’_en', 'pouvoir_s’_en_débarrasser', 's’_en_débarrasser_qu’', 'en_débarrasser_qu’_en', 'débarrasser_qu’_en_le', 'qu’_en_le_jeter', 'en_le_jeter_dans', 'le_jeter_dans_un', 'jeter_dans_un_livre', 'dans_un_livre_de', 'un_livre_de_ce', 'livre_de_ce_deux', 'de_ce_deux_explication', 'ce_deux_explication_le', 'deux_explication_le_lecteur', 'explication_le_lecteur_choisir', 'le_lecteur_choisir_celui', 'lecteur_choisir_celui_qu’', 'choisir_celui_qu’_il', 'celui_qu’_il_vouloir', 'qu’_il_vouloir_comme', 'il_vouloir_comme_on', 'vouloir_comme_on_le', 'comme_on_le_voir', 'on_le_voir_à', 'le_voir_à_l’', 'voir_à_l’_époque', 'à_l’_époque_où', 'l’_époque_où_ce', 'époque_où_ce_livre', 'où_ce_livre_être', 'ce_livre_être_publié', 'livre_être_publié_l’', 'être_publié_l’_auteur', 'publié_l’_auteur_ne', 'l’_auteur_ne_juger', 'auteur_ne_juger_pas', 'ne_juger_pas_à', 'juger_pas_à_propos', 'pas_à_propos_de', 'à_propos_de_dire', 'propos_de_dire_dès', 'de_dire_dès_lors', 'dire_dès_lors_tout', 'dès_lors_tout_son', 'lors_tout_son_pensée', 'tout_son_pensée_il', 'son_pensée_il_aimer', 'pensée_il_aimer_mieux', 'il_aimer_mieux_attendre', 'aimer_mieux_attendre_qu’', 'mieux_at ...

# %%
Counter(list_ngram_hugo).most_common(5)
# Out:
# [('le_peine_de_mort', 43),
#  ('il_y_avoir_un', 25),
#  ('qu’_il_y_avoir', 20),
#  ('il_n’_y_avoir', 19),
#  ('de_le_peine_de', 17)]

# %%
list_ngram_pos_hugo = ngrammize(list_pos_hugo, 4)    
print(list_ngram_pos_hugo)
# Out:
# ['PRON_ADV_PRON_VERB', 'ADV_PRON_VERB_ADP', 'PRON_VERB_ADP_NOUN', 'VERB_ADP_NOUN_DET', 'ADP_NOUN_DET_ADJ', 'NOUN_DET_ADJ_NOUN', 'DET_ADJ_NOUN_ADP', 'ADJ_NOUN_ADP_DET', 'NOUN_ADP_DET_NOUN', 'ADP_DET_NOUN_VERB', 'DET_NOUN_VERB_ADP', 'NOUN_VERB_ADP_ADV', 'VERB_ADP_ADV_ADP', 'ADP_ADV_ADP_NOUN', 'ADV_ADP_NOUN_ADP', 'ADP_NOUN_ADP_NOUN', 'NOUN_ADP_NOUN_SCONJ', 'ADP_NOUN_SCONJ_DET', 'NOUN_SCONJ_DET_DET', 'SCONJ_DET_DET_NOUN', 'DET_DET_NOUN_PRON', 'DET_NOUN_PRON_PRON', 'NOUN_PRON_PRON_VERB', 'PRON_PRON_VERB_VERB', 'PRON_VERB_VERB_PRON', 'VERB_VERB_PRON_PRON', 'VERB_PRON_PRON_VERB', 'PRON_PRON_VERB_NUM', 'PRON_VERB_NUM_NOUN', 'VERB_NUM_NOUN_ADP', 'NUM_NOUN_ADP_PRON', 'NOUN_ADP_PRON_VERB', 'ADP_PRON_VERB_NOUN', 'PRON_VERB_NOUN_ADP', 'VERB_NOUN_ADP_DET', 'NOUN_ADP_DET_NOUN', 'ADP_DET_NOUN_ADP', 'DET_NOUN_ADP_DET', 'NOUN_ADP_DET_NOUN', 'ADP_DET_NOUN_CCONJ', 'DET_NOUN_CCONJ_PRON', 'NOUN_CCONJ_PRON_PRON', 'CCONJ_PRON_PRON_AUX', 'PRON_PRON_AUX_VERB', 'PRON_AUX_VERB_ADP', 'AUX_VERB_ADP_NOUN', 'VERB_ADP_NOUN_DET', 'ADP_NOUN_DET_NOUN', 'NOUN_DET_NOUN_ADP', 'DET_NOUN_ADP_NOUN', 'NOUN_ADP_NOUN_ADJ', 'ADP_NOUN_ADJ_CCONJ', 'NOUN_ADJ_CCONJ_NOUN', 'ADJ_CCONJ_NOUN_ADP', 'CCONJ_NOUN_ADP_PRON', 'NOUN_ADP_PRON_PRON', 'ADP_PRON_PRON_AUX', 'PRON_PRON_AUX_VERB', 'PRON_AUX_VERB_VERB', 'AUX_VERB_VERB_DET', 'VERB_VERB_DET_NOUN', 'VERB_DET_NOUN_DET', 'DET_NOUN_DET_DET', 'NOUN_DET_DET_NOUN', 'DET_DET_NOUN_VERB', 'DET_NOUN_VERB_ADP', 'NOUN_VERB_ADP_DET', 'VERB_ADP_DET_NOUN', 'ADP_DET_NOUN_CCONJ', 'DET_NOUN_CCONJ_PRON', 'NOUN_CCONJ_PRON_PRON', 'CCONJ_PRON_PRON_AUX', 'PRON_PRON_AUX_ADJ', 'PRON_AUX_ADJ_DET', 'AUX_ADJ_DET_NOUN', 'ADJ_DET_NOUN_DET', 'DET_NOUN_DET_NOUN', 'NOUN_DET_NOUN_PROPN', 'DET_NOUN_PROPN_ADP', 'NOUN_PROPN_ADP_VERB', 'PROPN_ADP_VERB_DET', 'ADP_VERB_DET_NOUN', 'VERB_DET_NOUN_ADP', 'DET_NOUN_ADP_NOUN', 'NOUN_ADP_NOUN_ADP', 'ADP_NOUN_ADP_DET', 'NOUN_ADP_DET_NOUN', 'ADP_DET_NOUN_DET', 'DET_NOUN_DET_NOUN', 'NOUN_DET_NOUN_DET', 'DET_NOUN_DET_NOUN', 'NOUN_DET_NOUN_SCONJ', 'DET_NOUN_SCONJ_VERB', 'NOUN_SCONJ_VERB_PRON', 'SCONJ_VERB_PRON_PRON', 'VERB_PRON_PRON_DET', 'PRON_PRON_DET_NOUN', 'PRON_DET_NOUN_VERB', 'DET_NOUN_VERB_VERB', 'NOUN_VERB_VERB_DET', 'VERB_VERB_DET_NOUN', 'VERB_DET_NOUN_PRON', 'DET_NOUN_PRON_PRON', 'NOUN_PRON_PRON_AUX', 'PRON_PRON_AUX_VERB', 'PRON_AUX_VERB_CCONJ', 'AUX_VERB_CCONJ_SYM', 'VERB_CCONJ_SYM_PRON', 'CCONJ_SYM_PRON_AUX', 'SYM_PRON_AUX_VERB', 'PRON_AUX_VERB_VERB', 'AUX_VERB_VERB_ADP', 'VERB_VERB_ADP_PRON', 'VERB_ADP_PRON_CCONJ', 'ADP_PRON_CCONJ_ADV', 'PRON_CCONJ_ADV_AUX', 'CCONJ_ADV_AUX_VERB', 'ADV_AUX_VERB_PRON', 'AUX_VERB_PRON_ADP', 'VERB_PRON_ADP_VERB', 'PRON_ADP_VERB_SCONJ', 'ADP_VERB_SCONJ_ADP', 'VERB_SCONJ_ADP_DET', 'SCONJ_ADP_DET_VERB', 'ADP_DET_VERB_ADP', 'DET_VERB_ADP_DET', 'VERB_ADP_DET_NOUN', 'ADP_DET_NOUN_ADP', 'DET_NOUN_ADP_DET', 'NOUN_ADP_DET_NUM', 'ADP_DET_NUM_NOUN', 'DET_NUM_NOUN_DET', 'NUM_NOUN_DET_NOUN', 'NOUN_DET_NOUN_VERB', 'DET_NOUN_VERB_PRON', 'NOUN_VERB_PRON_PRON', 'VERB_PRON_PRON_PRON', 'PRON_PRON_PRON_VERB', 'PRON_PRON_VERB_SCONJ', 'PRON_VERB_SCONJ_PRON', 'VERB_SCONJ_PRON_PRON', 'SCONJ_PRON_PRON_VERB', 'PRON_PRON_VERB_ADP', 'PRON_VERB_ADP_DET', 'VERB_ADP_DET_NOUN', 'ADP_DET_NOUN_ADP', 'DET_NOUN_ADP_DET', 'NOUN_ADP_DET_NOUN', 'ADP_DET_NOUN_AUX', 'DET_NOUN_AUX_VERB', 'NOUN_AUX_VERB_DET', 'AUX_VERB_DET_NOUN', 'VERB_DET_NOUN_ADV', 'DET_NOUN_ADV_VERB', 'NOUN_ADV_VERB_ADV', 'ADV_VERB_ADV_ADP', 'VERB_ADV_ADP_NOUN', 'ADV_ADP_NOUN_ADP', 'ADP_NOUN_ADP_VERB', 'NOUN_ADP_VERB_ADP', 'ADP_VERB_ADP_ADV', 'VERB_ADP_ADV_ADJ', 'ADP_ADV_ADJ_DET', 'ADV_ADJ_DET_VERB', 'ADJ_DET_VERB_PRON', 'DET_VERB_PRON_VERB', 'VERB_PRON_VERB_ADV', 'PRON_VERB_ADV_VERB', 'VERB_ADV_VERB_SCONJ', 'ADV_VERB_SCONJ_PRON', 'VERB_SCONJ_PRON_NOUN', 'SCONJ_PRON_NOUN_VERB', 'PRON_NOUN_VERB_CCONJ', 'NOUN_VERB_CCONJ_VERB', 'VERB_CCONJ_VERB_SCONJ', 'CCONJ_VERB_SCONJ_PRON', 'VERB_SCONJ_PRON_PRON', 'SCONJ_PRON_PRON_AUX', 'PRON_PRON_AUX_PRON', 'PRON_AUX_PRON_PRON', 'AUX_PRON_PRON_AUX', 'PRON_PRON_AUX_VERB', 'PRON_AUX_VERB_DET', 'AUX_VERB_DET_NOUN', 'VERB_DET_NOUN_ ...

# %%
Counter(list_ngram_pos_hugo).most_common(5)
# Out:
# [('NOUN_ADP_DET_NOUN', 634),
#  ('DET_NOUN_ADP_NOUN', 563),
#  ('ADP_DET_NOUN_ADP', 456),
#  ('DET_NOUN_ADP_DET', 392),
#  ('PRON_VERB_DET_NOUN', 378)]

# %% [markdown]
# pour mesurer le temps d'exec du code d'une cellule

# %%
import timeit

# %%
start_time = timeit.default_timer()
# code you want to evaluate
elapsed = timeit.default_timer() - start_time

# %% [markdown]
# pour resoudre les problemes du '\xa0'

# %%
import unicodedata

# %%
text_string = BeautifulSoup(raw_html, "lxml").text
clean_text = unicodedata.normalize("NFKD",text_string)
print clean_text
